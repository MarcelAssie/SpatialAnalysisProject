# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\jeanm\Desktop\Ensg\Semestre5\ProjetStatAnalyseSpat\data\output\global_data"
analytic_data_path = path + r"\analytic_data.csv"
descriptive_data_path = path + r"\descriptive_data.csv"

# %%
analytic_data = pd.read_csv(analytic_data_path, delimiter=",")
descriptive_data = pd.read_csv(descriptive_data_path, delimiter=",")
# Out:
#       COM_ORG  COM_DEST  DELTA_PART_MP  DELTA_PART_TC  DELTA_PART_VT  \
# 0       75056     77005       0.000000       0.000000       0.689585
# 1       75056     77005       0.000000       0.000000       0.000000
# 2       75056     77005       0.000000       0.000000       0.000000
# 3       75056     77005       0.000000       0.253188      -0.253188
# 4       75056     77005       0.000000       0.132615      -0.132615
# ...       ...       ...            ...            ...            ...
# 2260    75056     95680       0.000000       0.558162      -0.133816
# 2261    75056     95680       0.040271       0.150151      -0.186931
# 2262    75056     95680       0.002340       0.002328      -0.005510
# 2263    75056     95680       0.002576       0.087119      -0.067683
# 2264    75056     95680       0.035812      -0.126370       0.043249
#
#       DELTA_PART_DRM  DELTA_PART_VL  DELTA_DUREE
# 0          -0.689585       0.000000    -3.769211
# 1           0.000000       0.000000     0.618607
# 2           0.000000       0.000000     4.310077
# 3           0.000000       0.000000    -0.952812
# 4           0.000000       0.000000    -7.715096
# ...              ...            ...          ...
# 2260       -0.407330      -0.017016    -0.288464
# 2261       -0.002414      -0.001078    -3.205390
# 2262        0.000961      -0.000119     0.074725
# 2263       -0.021685      -0.000327     0.957447
# 2264        0.000000       0.047309    -1.379599
#
# [2265 rows x 8 columns]
